# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("census_data_raw.csv")

# %%
df
# Out:
#      col_1  prefectures_2000   area_codes_2000   areas_in_2000  \
# 0        a          00_Japan                 0          2000.0
# 1        a       01_Hokkaido              1000          2000.0
# 2        1       01_Hokkaido              1100          2000.0
# 3        0       01_Hokkaido              1101          2000.0
# 4        0       01_Hokkaido              1102          2000.0
# ...    ...               ...               ...             ...
# 4081     9    47_Okinawa-ken             47343          2000.0
# 4082     9    47_Okinawa-ken             47344          2000.0
# 4083     3    47_Okinawa-ken             47375          2000.0
# 4084     3    47_Okinawa-ken             47381          2000.0
# 4085     3    47_Okinawa-ken             47382          2000.0
#
#       prefectures_2020  area_codes_2020  \
# 0             00_Japan                0
# 1          01_Hokkaido             1000
# 2          01_Hokkaido             1100
# 3          01_Hokkaido             1101
# ...

# %%
df = df.replace("-", "NULL")
df = df.drop(columns=["col_1"])

# %%
df.to_csv("census_data_raw_fixed.csv")
